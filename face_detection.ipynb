# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('data/download.jpeg')

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
cv2.imshow('mohanlal',img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
#converting to grey

img_grey=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
#reading or storing haarcascade files(face)

face_cascade=cv2.CascadeClassifier('data/haarcascade_frontalface_default.xml')

# %%
#variable for saving detected faces

faces=face_cascade.detectMultiScale(img_grey)

# %%
len(faces)
# Out:
# 1

# %%
faces
# Out:
# array([[96, 36, 98, 98]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),color=(0,255,0),thickness=2)

# %%
cv2.imshow('face detection',img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
